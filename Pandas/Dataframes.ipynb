# %%
import pandas as pd
import numpy as np

# %%
dframe=pd.read_clipboard()

# %%
d=[{
    "ID": 1,
    "Address": "3666 21st St",
    "City": "San Francisco",
    "State": "CA 94114",
    "Country": "USA",
    "Name": "Madeira",
    "Employees": 8
  },
  {
    "ID": 2,
    "Address": "735 Dolores St",
    "City": "San Francisco",
    "State": "CA 94119",
    "Country": "USA",
    "Name": "Bready Shop",
    "Employees": 15
  },
  {
    "ID": 3,
    "Address": "332 Hill St",
    "City": "San Francisco",
    "State": "California 94114",
    "Country": "USA",
    "Name": "Super River",
    "Employees": 25
  },
  {
    "ID": 4,
    "Address": "3995 23rd St",
    "City": "San Francisco",
    "State": "CA 94114",
    "Country": "USA",
    "Name": "Ben's Shop",
    "Employees": 10
  },
  {
    "ID": 5,
    "Address": "1056 Sanchez St",
    "City": "San Francisco",
    "State": "California",
    "Country": "USA",
    "Name": "Sanchez",
    "Employees": 12
  },
  {
    "ID": 6,
    "Address": "551 Alvarado St",
    "City": "San Francisco",
    "State": "CA 94114",
    "Country": "USA",
    "Name": "Richvalley",
    "Employees": 20
  }
]

# %%
dframe=pd.DataFrame(d)

# %%
dframe
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dframe.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
dframe.Address
# Out:
# 0       3666 21st St
# 1     735 Dolores St
# 2        332 Hill St
# 3       3995 23rd St
# 4    1056 Sanchez St
# 5    551 Alvarado St
# Name: Address, dtype: object

# %%
dframe.State
# Out:
# 0            CA 94114
# 1            CA 94119
# 2    California 94114
# 3            CA 94114
# 4          California
# 5            CA 94114
# Name: State, dtype: object

# %%
dframe['Address']
# Out:
# 0       3666 21st St
# 1     735 Dolores St
# 2        332 Hill St
# 3       3995 23rd St
# 4    1056 Sanchez St
# 5    551 Alvarado St
# Name: Address, dtype: object

# %%
pd.DataFrame(dframe,columns=['Name','Country','Address'])
# Out:
#           Name Country          Address
# 0      Madeira     USA     3666 21st St
# 1  Bready Shop     USA   735 Dolores St
# 2  Super River     USA      332 Hill St
# 3   Ben's Shop     USA     3995 23rd St
# 4      Sanchez     USA  1056 Sanchez St
# 5   Richvalley     USA  551 Alvarado St

# %%
pd.DataFrame(dframe,columns=['Name','Country','Address','Type'])
# Out:
#           Name Country          Address  Type
# 0      Madeira     USA     3666 21st St   NaN
# 1  Bready Shop     USA   735 Dolores St   NaN
# 2  Super River     USA      332 Hill St   NaN
# 3   Ben's Shop     USA     3995 23rd St   NaN
# 4      Sanchez     USA  1056 Sanchez St   NaN
# 5   Richvalley     USA  551 Alvarado St   NaN

# %%
dframe['Type']='Shop'

# %%
dframe
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Type
# 0          8  Shop
# 1         15  Shop
# 2         25  Shop
# 3         10  Shop
# 4         12  Shop
# 5         20  Shop

# %%
dframe['Type']=np.arange(6)

# %%
dframe
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Type
# 0          8     0
# 1         15     1
# 2         25     2
# 3         10     3
# 4         12     4
# 5         20     5

# %%
ts=["shop",'store','saloon','Grocer','market','shopping mall']

# %%
dframe['Type']=ts

# %%
dframe
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees           Type
# 0          8           shop
# 1         15          store
# 2         25         saloon
# 3         10         Grocer
# 4         12         market
# 5         20  shopping mall

# %%
store=pd.Series(['Store','Shop'],index=[0,4])

# %%
store
# Out:
# 0    Store
# 4     Shop
# dtype: object

# %%
dframe['Type']=store

# %%
dframe
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees   Type
# 0          8  Store
# 1         15    NaN
# 2         25    NaN
# 3         10    NaN
# 4         12   Shop
# 5         20    NaN

# %%
del dframe['Type']

# %%
dframe
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dframe.head()
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12

# %%
dframe.head(2)
# Out:
#    ID         Address           City     State Country         Name  Employees
# 0   1    3666 21st St  San Francisco  CA 94114     USA      Madeira          8
# 1   2  735 Dolores St  San Francisco  CA 94119     USA  Bready Shop         15

# %%
dframe.tail()
# Out:
#    ID          Address           City             State Country         Name  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dframe.tail(2)
# Out:
#    ID          Address           City       State Country        Name  \
# 4   5  1056 Sanchez St  San Francisco  California     USA     Sanchez
# 5   6  551 Alvarado St  San Francisco    CA 94114     USA  Richvalley
#
#    Employees
# 4         12
# 5         20

# %%
dframe.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
dframe.values
# Out:
# array([[1, '3666 21st St', 'San Francisco', 'CA 94114', 'USA', 'Madeira',
#         8],
#        [2, '735 Dolores St', 'San Francisco', 'CA 94119', 'USA',
#         'Bready Shop', 15],
#        [3, '332 Hill St', 'San Francisco', 'California 94114', 'USA',
#         'Super River', 25],
#        [4, '3995 23rd St', 'San Francisco', 'CA 94114', 'USA',
#         "Ben's Shop", 10],
#        [5, '1056 Sanchez St', 'San Francisco', 'California', 'USA',
#         'Sanchez', 12],
#        [6, '551 Alvarado St', 'San Francisco', 'CA 94114', 'USA',
#         'Richvalley', 20]], dtype=object)

# %%
dframe.iloc[0]
# Out:
# ID                       1
# Address       3666 21st St
# City         San Francisco
# State             CA 94114
# Country                USA
# Name               Madeira
# Employees                8
# Name: 0, dtype: object

# %%
m={'NAme':['NK','PK','Mk'],'COmp':[100,95,85]}

# %%
m
# Out:
# {'NAme': ['NK', 'PK', 'Mk'], 'COmp': [100, 95, 85]}

# %%
r=pd.DataFrame(m)

# %%
r
# Out:
#   NAme  COmp
# 0   NK   100
# 1   PK    95
# 2   Mk    85

# %%
math=[45,85,95]

# %%
r['Maths']=math

# %%
r
# Out:
#   NAme  COmp  Maths
# 0   NK   100     45
# 1   PK    95     85
# 2   Mk    85     95

# %%
m['Hindi']=[85,87,85]

# %%
r
# Out:
#   NAme  COmp  Maths
# 0   NK   100     45
# 1   PK    95     85
# 2   Mk    85     95

# %%
r['Hindi']=m['Hindi']

# %%
r
# Out:
#   NAme  COmp  Maths  Hindi
# 0   NK   100     45     85
# 1   PK    95     85     87
# 2   Mk    85     95     85

# %%
pd.DataFrame(r,columns=['NAme','COmp','ENglish'])
# Out:
#   NAme  COmp  ENglish
# 0   NK   100      NaN
# 1   PK    95      NaN
# 2   Mk    85      NaN

# %%
dframe.iloc[1:]
# Out:
#    ID          Address           City             State Country         Name  \
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dframe.iloc[1]
# Out:
# ID                        2
# Address      735 Dolores St
# City          San Francisco
# State              CA 94119
# Country                 USA
# Name            Bready Shop
# Employees                15
# Name: 1, dtype: object

# %%
l1=[[1,2,3],[4,6,7]]

# %%
df=pd.DataFrame(l1,columns=['x','y','z'])

# %%
df
# Out:
#    x  y  z
# 0  1  2  3
# 1  4  6  7

# %%
l2=[[12,13,14],[43,64,87]]

# %%
df1=pd.DataFrame(l2,columns=['x','y','z'],index=[2,3])

# %%
df1
# Out:
#     x   y   z
# 2  12  13  14
# 3  43  64  87

# %%
df.append(df1)
# Out:
#     x   y   z
# 0   1   2   3
# 1   4   6   7
# 2  12  13  14
# 3  43  64  87
